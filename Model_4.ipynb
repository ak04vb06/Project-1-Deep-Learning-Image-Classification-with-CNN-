# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
from PIL import Image

# -----------------------------
# ⚙️ CONFIGURATION (change model = change paramethers)
# -----------------------------
DATASET_PATH = r"/Users/ia_dev/Desktop/Work/archive/raw-img" # need to change 
IMG_SIZE = 224
BATCH_SIZE = 100
EPOCHS = 30
RANDOM_SEED = 42

# -----------------------------
# 1️⃣ DATA PREPARATION & METADATA
# -----------------------------
data = []

# Converts folder structure into a clean list.
for folder in os.listdir(DATASET_PATH):
    folder_path = os.path.join(DATASET_PATH, folder)
    
    if os.path.isdir(folder_path):
        # Translate label 4 the folders
        label = folder
        
        for file in os.listdir(folder_path):
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(folder_path, file)
                data.append([img_path, label])

# Converts the raw list into a structured table (DataFrame)
df = pd.DataFrame(data, columns=["image_path", "label"])

# Identifies all unique categories and sorts them alphabetically
class_names = sorted(df['label'].unique())
# Creates a dictionary to map text labels to integer IDs (Model readable)
label_map = {name: i for i, name in enumerate(class_names)}
# Creates a reverse dictionary to map IDs back to text labels (Human readable)
inv_label_map = {i: name for name, i in label_map.items()}

# Map labels to integers immediately in the DataFrame
df['label_code'] = df['label'].map(label_map)

print(f"Total images: {len(df)}")
print(f"Classes found: {len(class_names)}")
print(df['label'].value_counts().head())

# -----------------------------
# 2️⃣ TRAIN / TEST SPLIT
# -----------------------------
train_df, test_df = train_test_split(
    df,
    test_size=0.1,
    stratify=df['label'], # Stratify ensures all classes are represented
    random_state=RANDOM_SEED
)

print(f"Train size: {len(train_df)} | Test size: {len(test_df)}")

# -----------------------------
# 3️⃣ DATASET PIPELINE (tf.data)
# -----------------------------
def df_to_dataset(dataframe, shuffle=True, batch_size=32):
    # Get the list of files and labels
    paths = dataframe['image_path'].values
    labels = dataframe['label_code'].values
    
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    # Define Image Processing (Load -> Resize -> Normalize)
    def process_path(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
        img = img / 255.0  # Normalize [0, 1]
        return img, label
    
    # Apply processing to all images in parallel
    ds = ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)

    # Aleatory combination
    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe))

    # Group into packs of 32
    ds = ds.batch(batch_size)
    #Preload next pack in background (No Lag)
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)
    return ds

# Create the final pipelines
train_dataset = df_to_dataset(train_df, batch_size=BATCH_SIZE)
test_dataset = df_to_dataset(test_df, shuffle=False, batch_size=BATCH_SIZE)

# -----------------------------
# 3️⃣.5️⃣ DATA AUGMENTATION 
# -----------------------------

# We define a temporary layer just to see the effects.
aug_layer = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(0.2),
])

plt.figure(figsize=(10, 10))
# We took 1 batch from the REAL training dataset.
for images, _ in train_dataset.take(1):
    first_image = images[0]
    
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        # We apply the transformation 9 times to the same image.
        augmented_image = aug_layer(tf.expand_dims(first_image, 0))
        
        # We display without dividing by 255 because they are already floats 0-1.
        plt.imshow(augmented_image[0])
        plt.axis('off')
        
plt.suptitle("Augmentation Preview", fontsize=16)
plt.show()

# -----------------------------
# 4️⃣ MODEL ARCHITECTURE (CNN)
# -----------------------------
# Data augmentation
data_augmentation = models.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(0.2),
])

model = models.Sequential([
    # Data augmentation
    layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3)),
    data_augmentation,

    # Block 1
    layers.Conv2D(32, 3, activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    layers.MaxPooling2D(),

    # Block 2
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),

    # Block 3
    layers.Conv2D(96, 3, activation='relu'),
    layers.MaxPooling2D(),

    # Global pooling is generally more efficient than Flatten for modern CNNs
    layers.GlobalAveragePooling2D(),

    # Dense Layers
    layers.Dense(96, activation='relu'),     # This change to model 1 and 2
    layers.Dropout(0.4), # Reduce overfitting

    # Output Layer 
    layers.Dense(len(class_names), activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# -----------------------------
# 5️⃣ TRAINING
# -----------------------------
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=EPOCHS
)

# -----------------------------
# 6️⃣ EVALUATION & VISUALIZATION
# -----------------------------
# Evaluate on test set
test_loss, test_acc = model.evaluate(test_dataset)

train_acc = history.history['accuracy'][-1]
train_loss = history.history['loss'][-1]

print(f'Accuracy (Train): {train_acc}')
print(f'Loss (Train): {train_loss}')
print(f'Validation accuracy: {test_acc}')
print(f'Loss validation: {test_loss}')

# Plot Training History 
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Val Loss', color='orange') # Added validation loss
plt.title('Cross Entropy Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy', color='green')
plt.plot(history.history['val_accuracy'], label='Val Accuracy', color='red') # Added validation acc
plt.title('Classification Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Visualize Predictions
print("\n--- Sample Predictions ---")
for images, labels in test_dataset.take(1):
    preds = model.predict(images)
    pred_classes = np.argmax(preds, axis=1)

    # Show first image in batch
    img = images[0].numpy()
    true_label = inv_label_map[labels[0].numpy()]
    pred_label = inv_label_map[pred_classes[0]]
    
    print(f"Predicted: {pred_label} | Actual: {true_label}")
    
    plt.imshow(img)
    plt.title(f"Pred: {pred_label} | True: {true_label}")
    plt.axis('off')
    plt.show()
    break
# Out:
# Total images: 26179
# Classes found: 10
# label
# cane        4863
# ragno       4821
# gallina     3098
# cavallo     2623
# farfalla    2112
# Name: count, dtype: int64
# Train size: 23561 | Test size: 2618
# 2026-01-29 12:19:53.796472: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:54.058408: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:54.189845: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:54.508810: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:54.579450: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:54.789920: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:54.911508: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:56.449781: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:56.488069: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:56.507223: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:56.572587: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:57.109266: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:57.902718: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:57.988146: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:58.321779: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:58.834905: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:58.867343: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:58.957387: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:58.988775: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:59.085238: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:19:59.853522: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /Users/ia_dev/Downloads/yes/envs/ia-audio/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_4 (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 52, 52, 96)     │        55,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 26, 26, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 96)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 96)             │         9,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           970 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 85,066 (332.29 KB)
#  Trainable params: 85,066 (332.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 2026-01-29 12:20:00.854866: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:01.118921: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:01.244955: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:01.565161: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:01.632015: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:01.822000: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:01.906912: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:02.732845: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:02.767047: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:02.777826: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:02.807625: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:03.103857: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:03.674968: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:03.728637: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:03.975647: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:04.286680: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:04.303244: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:04.597993: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:04.695135: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:04.991927: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.1847 - loss: 2.2049
# 2026-01-29 12:20:34.385352: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:34.600126: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 35s 121ms/step - accuracy: 0.1988 - loss: 2.1688 - val_accuracy: 0.2212 - val_loss: 2.1940
# Epoch 2/30
# 2026-01-29 12:20:35.594639: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:35.869396: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:36.018166: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:36.352213: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:36.425420: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:36.638685: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:36.736131: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:37.675763: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:37.716667: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:37.730134: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:37.769134: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:38.124515: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:38.778875: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:38.845152: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:39.154502: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:39.500031: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:39.517690: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:39.574268: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:39.600728: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:20:39.684755: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.2167 - loss: 2.1250
# 2026-01-29 12:21:06.236677: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:06.365651: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 32s 111ms/step - accuracy: 0.2209 - loss: 2.1334 - val_accuracy: 0.2972 - val_loss: 1.9988
# Epoch 3/30
# 2026-01-29 12:21:07.115680: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:07.383881: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:07.520144: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:07.890357: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:07.964560: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:08.187199: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:08.286149: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:09.291506: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:09.336360: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:09.350566: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:09.390821: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:09.760939: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:10.430386: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:10.508279: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:10.821136: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:11.181310: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:11.200279: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:11.256002: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:11.279686: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:11.377848: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.2204 - loss: 2.1724
# 2026-01-29 12:21:38.682002: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:38.811547: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 32s 114ms/step - accuracy: 0.2220 - loss: 2.1742 - val_accuracy: 0.2647 - val_loss: 2.1311
# Epoch 4/30
# 2026-01-29 12:21:39.570473: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:39.849550: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:39.989742: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:40.342301: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:40.419381: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:40.640512: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:40.739866: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:41.712051: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:41.752988: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:41.765976: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:41.805458: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:42.191936: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:42.858172: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:42.929713: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:43.223827: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:43.573461: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:43.594253: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:43.656855: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:43.681893: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:21:43.785289: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.2353 - loss: 2.1595
# 2026-01-29 12:22:11.860467: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:11.989743: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 33s 117ms/step - accuracy: 0.2402 - loss: 2.1501 - val_accuracy: 0.2743 - val_loss: 2.0467
# Epoch 5/30
# 2026-01-29 12:22:12.757447: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:13.038609: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:13.180190: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:13.530806: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:13.605997: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:13.827599: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:13.931766: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:14.906656: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:14.945686: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:14.958538: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:14.996606: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:15.361817: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:16.054346: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:16.139680: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:16.427578: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:16.753996: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:16.772438: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:16.829103: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:16.852191: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:16.942826: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.2464 - loss: 2.1224
# 2026-01-29 12:22:44.751709: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:44.888125: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 33s 116ms/step - accuracy: 0.2527 - loss: 2.1052 - val_accuracy: 0.2907 - val_loss: 2.0217
# Epoch 6/30
# 2026-01-29 12:22:45.689971: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:45.966873: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:46.103551: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:46.441551: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:46.515004: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:46.730957: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:46.835191: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:47.827310: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:47.868651: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:47.883102: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:47.924781: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:48.326252: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:48.984812: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:49.051540: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:49.369594: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:49.705407: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:49.731348: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:49.800178: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:49.832792: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:22:49.957708: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.2716 - loss: 2.0725
# 2026-01-29 12:23:17.433935: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:17.557737: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 33s 115ms/step - accuracy: 0.2698 - loss: 2.0680 - val_accuracy: 0.3167 - val_loss: 1.9535
# Epoch 7/30
# 2026-01-29 12:23:18.415342: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:18.728170: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:18.874500: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:19.226654: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:19.304314: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:19.526975: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:19.628877: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:20.585699: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:20.628301: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:20.641530: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:20.679126: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:21.039537: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:21.705935: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:21.775558: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:22.065531: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:22.432063: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:22.449354: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:22.502947: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:22.524576: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:22.607853: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.2718 - loss: 2.0452
# 2026-01-29 12:23:50.898216: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:51.032221: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 33s 117ms/step - accuracy: 0.2728 - loss: 2.0442 - val_accuracy: 0.2777 - val_loss: 2.0733
# Epoch 8/30
# 2026-01-29 12:23:51.874814: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:52.176278: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:52.337554: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:52.694920: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:52.770578: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:52.990050: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:53.091561: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:54.090596: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:54.133793: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:54.148492: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:54.188672: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:54.543091: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:55.207130: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:55.283844: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:55.581036: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:55.917713: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:55.936743: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:56.007707: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:56.034700: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:23:56.138110: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2764 - loss: 2.0540
# 2026-01-29 12:24:25.003309: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:25.141545: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 34s 120ms/step - accuracy: 0.2766 - loss: 2.0517 - val_accuracy: 0.3086 - val_loss: 2.0250
# Epoch 9/30
# 2026-01-29 12:24:25.991160: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:26.304383: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:26.451535: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:26.806419: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:26.882009: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:27.105126: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:27.217865: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:28.176687: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:28.216905: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:28.230558: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:28.270183: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:28.627036: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:29.306395: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:29.374317: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:29.669392: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:30.006075: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:30.023283: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:30.079254: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:30.103874: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:30.186143: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.2813 - loss: 2.0314
# 2026-01-29 12:24:57.298547: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:57.424051: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 32s 113ms/step - accuracy: 0.2840 - loss: 2.0449 - val_accuracy: 0.2899 - val_loss: 2.2011
# Epoch 10/30
# 2026-01-29 12:24:58.171712: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:58.445510: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:58.580118: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:58.909972: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:58.981438: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:59.195310: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:24:59.289833: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:00.212009: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:00.250465: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:00.263630: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:00.301479: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:00.647044: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:01.306790: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:01.377225: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:01.683880: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:02.034916: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:02.054174: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:02.112945: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:02.135028: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:02.219458: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.2911 - loss: 2.0369
# 2026-01-29 12:25:29.062863: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:29.184621: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 32s 111ms/step - accuracy: 0.2890 - loss: 2.0349 - val_accuracy: 0.3312 - val_loss: 1.9687
# Epoch 11/30
# 2026-01-29 12:25:29.916355: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:30.193108: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:30.329313: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:30.673853: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:30.747711: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:30.961875: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:31.061843: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:32.002758: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:32.043048: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:32.056221: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:32.093927: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:32.456601: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:33.115383: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:33.185127: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:33.467236: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:33.795980: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:33.814553: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:33.871845: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:33.896470: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:25:33.981582: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.2971 - loss: 2.0155
# 2026-01-29 12:26:01.111008: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:01.239318: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 32s 113ms/step - accuracy: 0.2977 - loss: 2.0197 - val_accuracy: 0.2964 - val_loss: 2.0229
# Epoch 12/30
# 2026-01-29 12:26:01.997214: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:02.268590: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:02.406724: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:02.739439: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:02.816611: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:03.030580: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:03.126505: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:04.075901: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:04.115344: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:04.128169: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:04.165564: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:04.534170: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:05.194430: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:05.261522: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:05.549678: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:05.889482: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:05.908725: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:05.961770: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:05.988830: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:06.079272: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.2917 - loss: 2.0444
# 2026-01-29 12:26:32.971482: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:33.101025: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 32s 111ms/step - accuracy: 0.2954 - loss: 2.0366 - val_accuracy: 0.2689 - val_loss: 2.2773
# Epoch 13/30
# 2026-01-29 12:26:33.854624: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:34.141558: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:34.287801: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:34.621700: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:34.693871: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:34.909505: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:35.006676: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:35.947630: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:35.986168: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:35.999543: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:36.043665: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:36.401977: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:37.050401: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:37.116646: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:37.395125: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:37.717747: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:37.735163: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:37.807606: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:37.837931: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:26:37.937399: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.2914 - loss: 2.0608
# 2026-01-29 12:27:04.688027: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:04.828253: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 32s 112ms/step - accuracy: 0.2984 - loss: 2.0519 - val_accuracy: 0.3686 - val_loss: 1.8500
# Epoch 14/30
# 2026-01-29 12:27:05.581569: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:05.857799: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:05.990013: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:06.317915: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:06.391316: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:06.603074: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:06.698048: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:07.624118: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:07.662462: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:07.675424: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:07.712767: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:08.090656: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:08.725205: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:08.790240: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:09.074165: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:09.393940: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:09.418092: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:09.484305: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:09.522987: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:09.635640: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.3043 - loss: 2.0462
# 2026-01-29 12:27:35.617153: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:35.757152: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 31s 109ms/step - accuracy: 0.3016 - loss: 2.0511 - val_accuracy: 0.2949 - val_loss: 2.1444
# Epoch 15/30
# 2026-01-29 12:27:36.551397: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:36.819496: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:36.954458: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:37.282456: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:37.356015: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:37.565449: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:37.657422: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:38.568324: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:38.606439: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:38.619454: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:38.655910: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:38.996534: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:39.653368: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:39.719050: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:40.002775: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:40.328585: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:40.348515: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:40.406042: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:40.426434: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:27:40.527855: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.3042 - loss: 2.0615
# 2026-01-29 12:28:06.819214: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:28:06.956816: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 31s 110ms/step - accuracy: 0.3022 - loss: 2.0794 - val_accuracy: 0.3006 - val_loss: 2.0678
# Epoch 16/30
# 2026-01-29 12:28:07.744300: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:28:08.013832: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:28:08.149761: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:28:08.479421: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:28:08.552924: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:28:08.777406: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:28:08.877193: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:28:09.829507: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:28:09.867237: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:28:09.880889: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:28:09.921281: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:28:10.273569: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# ...
# 2026-01-29 12:33:05.573057: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:06.278788: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:06.352328: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:06.651622: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:06.989154: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:07.014628: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:07.087226: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:07.109643: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:07.205177: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.3075 - loss: 2.1488
# 2026-01-29 12:33:39.357674: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:39.526556: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 37s 135ms/step - accuracy: 0.3085 - loss: 2.1490 - val_accuracy: 0.3323 - val_loss: 2.2588
# Epoch 26/30
# 2026-01-29 12:33:40.370856: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:40.645155: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:40.783068: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:41.138908: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:41.214452: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:41.432936: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:41.533730: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:42.508055: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:42.551242: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:42.565630: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:42.604028: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:42.973680: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:43.641713: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:43.723559: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:44.015107: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:44.359717: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:44.377118: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:44.436824: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:44.461552: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:33:44.586906: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3072 - loss: 2.1552
# 2026-01-29 12:34:17.059346: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:17.193388: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 38s 136ms/step - accuracy: 0.3080 - loss: 2.1505 - val_accuracy: 0.2876 - val_loss: 2.2890
# Epoch 27/30
# 2026-01-29 12:34:18.075994: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:18.361436: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:18.501469: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:18.847232: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:18.920807: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:19.136268: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:19.232852: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:20.199100: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:20.242953: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:20.256529: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:20.297287: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:20.663031: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:21.341624: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:21.453156: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:21.751745: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:22.098212: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:22.117021: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:22.178697: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:22.201610: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:22.338215: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.3208 - loss: 2.1125
# 2026-01-29 12:34:54.319496: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:54.451047: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 37s 134ms/step - accuracy: 0.3154 - loss: 2.1254 - val_accuracy: 0.3938 - val_loss: 1.8971
# Epoch 28/30
# 2026-01-29 12:34:55.317217: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:55.594043: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:55.732120: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:56.073595: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:56.151113: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:56.371131: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:56.471378: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:57.436299: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:57.476965: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:57.491421: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:57.534921: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:57.907663: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:58.593415: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:58.664153: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:58.949206: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:59.281582: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:59.299665: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:59.357941: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:59.381727: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:34:59.478022: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.3159 - loss: 2.1913
# 2026-01-29 12:35:30.966112: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:31.083968: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 37s 132ms/step - accuracy: 0.3088 - loss: 2.2241 - val_accuracy: 0.3147 - val_loss: 2.4302
# Epoch 29/30
# 2026-01-29 12:35:31.983161: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:32.263434: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:32.398055: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:32.736661: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:32.811105: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:33.032970: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:33.204657: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:34.283491: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:34.335718: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:34.352832: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:34.409694: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:34.811769: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:35.517657: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:35.592743: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:35.908842: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:36.283706: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:36.300855: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:36.356641: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:36.380467: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:35:36.464226: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.3091 - loss: 2.2288
# 2026-01-29 12:36:06.130617: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:06.267626: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 35s 122ms/step - accuracy: 0.3100 - loss: 2.2050 - val_accuracy: 0.3640 - val_loss: 2.1411
# Epoch 30/30
# 2026-01-29 12:36:07.181303: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:07.457924: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:07.598767: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:07.973066: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:08.051521: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:08.274582: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:08.377165: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:09.365614: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:09.408967: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:09.423240: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:09.462374: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:09.845840: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:10.552493: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:10.620180: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:10.922000: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:11.270472: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:11.295410: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:11.354833: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:11.378626: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:11.474579: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.3084 - loss: 2.2466
# 2026-01-29 12:36:42.825566: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:42.961724: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 37s 131ms/step - accuracy: 0.3084 - loss: 2.2346 - val_accuracy: 0.2846 - val_loss: 2.2311
#  6/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3157 - loss: 2.2568
# 2026-01-29 12:36:43.497410: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:36:43.632892: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2846 - loss: 2.2311
# Accuracy (Train): 0.3084334135055542
# Loss (Train): 2.2346415519714355
# Validation accuracy: 0.2845683693885803
# Loss validation: 2.2311253547668457
# --- Sample Predictions ---
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Predicted: farfalla | Actual: ragno
