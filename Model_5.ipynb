# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
from PIL import Image

# -----------------------------
# ⚙️ CONFIGURATION (change model = change paramethers)
# -----------------------------
DATASET_PATH = r"/Users/ia_dev/Desktop/Work/archive/raw-img" # need to change 
IMG_SIZE = 224
BATCH_SIZE = 100
EPOCHS = 30
RANDOM_SEED = 42

# -----------------------------
# 1️⃣ DATA PREPARATION & METADATA
# -----------------------------
data = []

# Converts folder structure into a clean list.
for folder in os.listdir(DATASET_PATH):
    folder_path = os.path.join(DATASET_PATH, folder)
    
    if os.path.isdir(folder_path):
        # Translate label 4 the folders
        label = folder
        
        for file in os.listdir(folder_path):
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(folder_path, file)
                data.append([img_path, label])

# Converts the raw list into a structured table (DataFrame)
df = pd.DataFrame(data, columns=["image_path", "label"])

# Identifies all unique categories and sorts them alphabetically
class_names = sorted(df['label'].unique())
# Creates a dictionary to map text labels to integer IDs (Model readable)
label_map = {name: i for i, name in enumerate(class_names)}
# Creates a reverse dictionary to map IDs back to text labels (Human readable)
inv_label_map = {i: name for name, i in label_map.items()}

# Map labels to integers immediately in the DataFrame
df['label_code'] = df['label'].map(label_map)

print(f"Total images: {len(df)}")
print(f"Classes found: {len(class_names)}")
print(df['label'].value_counts().head())

# -----------------------------
# 2️⃣ TRAIN / TEST SPLIT
# -----------------------------
train_df, test_df = train_test_split(
    df,
    test_size=0.1,
    stratify=df['label'], # Stratify ensures all classes are represented
    random_state=RANDOM_SEED
)

print(f"Train size: {len(train_df)} | Test size: {len(test_df)}")

# -----------------------------
# 3️⃣ DATASET PIPELINE (tf.data)
# -----------------------------
def df_to_dataset(dataframe, shuffle=True, batch_size=32):
    # Get the list of files and labels
    paths = dataframe['image_path'].values
    labels = dataframe['label_code'].values
    
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    # Define Image Processing (Load -> Resize -> Normalize)
    def process_path(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
        img = img / 255.0  # Normalize [0, 1]
        return img, label
    
    # Apply processing to all images in parallel
    ds = ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)

    # Aleatory combination
    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe))

    # Group into packs of 32
    ds = ds.batch(batch_size)
    #Preload next pack in background (No Lag)
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)
    return ds

# Create the final pipelines
train_dataset = df_to_dataset(train_df, batch_size=BATCH_SIZE)
test_dataset = df_to_dataset(test_df, shuffle=False, batch_size=BATCH_SIZE)

# -----------------------------
# 3️⃣.5️⃣ DATA AUGMENTATION 
# -----------------------------

# We define a temporary layer just to see the effects.
aug_layer = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(0.2),
])

plt.figure(figsize=(10, 10))
# We took 1 batch from the REAL training dataset.
for images, _ in train_dataset.take(1):
    first_image = images[0]
    
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        # We apply the transformation 9 times to the same image.
        augmented_image = aug_layer(tf.expand_dims(first_image, 0))
        
        # We display without dividing by 255 because they are already floats 0-1.
        plt.imshow(augmented_image[0])
        plt.axis('off')
        
plt.suptitle("Augmentation Preview", fontsize=16)
plt.show()

# -----------------------------
# 4️⃣ MODEL ARCHITECTURE (CNN)
# -----------------------------
# Data augmentation
data_augmentation = models.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(0.2),
])

model = models.Sequential([
    # Data augmentation
    layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3)),
    data_augmentation,

    # Block 1
    layers.Conv2D(32, 3, activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    layers.MaxPooling2D(),

    # Block 2
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),

    # Block 3
    layers.Conv2D(96, 3, activation='relu'),
    layers.MaxPooling2D(),

    # Global pooling is generally more efficient than Flatten for modern CNNs
    layers.GlobalAveragePooling2D(),

    # Dense Layers
    layers.Dense(200, activation='relu'),     # This change to model 1 and 2
    layers.Dropout(0.4), # Reduce overfitting

    # Output Layer 
    layers.Dense(len(class_names), activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# -----------------------------
# 5️⃣ TRAINING
# -----------------------------
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=EPOCHS
)

# -----------------------------
# 6️⃣ EVALUATION & VISUALIZATION
# -----------------------------
# Evaluate on test set
test_loss, test_acc = model.evaluate(test_dataset)

train_acc = history.history['accuracy'][-1]
train_loss = history.history['loss'][-1]

print(f'Accuracy (Train): {train_acc}')
print(f'Loss (Train): {train_loss}')
print(f'Validation accuracy: {test_acc}')
print(f'Loss validation: {test_loss}')

# Plot Training History 
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Val Loss', color='orange') # Added validation loss
plt.title('Cross Entropy Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy', color='green')
plt.plot(history.history['val_accuracy'], label='Val Accuracy', color='red') # Added validation acc
plt.title('Classification Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Visualize Predictions
print("\n--- Sample Predictions ---")
for images, labels in test_dataset.take(1):
    preds = model.predict(images)
    pred_classes = np.argmax(preds, axis=1)

    # Show first image in batch
    img = images[0].numpy()
    true_label = inv_label_map[labels[0].numpy()]
    pred_label = inv_label_map[pred_classes[0]]
    
    print(f"Predicted: {pred_label} | Actual: {true_label}")
    
    plt.imshow(img)
    plt.title(f"Pred: {pred_label} | True: {true_label}")
    plt.axis('off')
    plt.show()
    break
# Out:
# Total images: 26179
# Classes found: 10
# label
# cane        4863
# ragno       4821
# gallina     3098
# cavallo     2623
# farfalla    2112
# Name: count, dtype: int64
# Train size: 23561 | Test size: 2618
# 2026-01-29 12:56:36.891724: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Max
# 2026-01-29 12:56:36.891749: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 36.00 GB
# 2026-01-29 12:56:36.891753: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 14.04 GB
# 2026-01-29 12:56:36.891766: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-01-29 12:56:36.891775: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2026-01-29 12:56:37.331284: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:37.594915: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:37.732901: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:38.053642: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:38.130692: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:38.366424: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:38.455041: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:39.372394: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:39.409445: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:39.421706: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:39.454420: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:39.804989: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:40.427138: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:40.490979: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:40.757945: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:41.065991: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:41.081536: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:41.136964: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:41.166080: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:41.252344: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 12:56:41.987251: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /Users/ia_dev/Downloads/yes/envs/ia-audio/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 96)     │        55,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 96)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 200)            │        19,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 96,194 (375.76 KB)
#  Trainable params: 96,194 (375.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
#