# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
from PIL import Image

# -----------------------------
# ⚙️ CONFIGURATION (change model = change paramethers)
# -----------------------------
DATASET_PATH = r"/Users/ia_dev/Desktop/Work/archive/raw-img" # need to change 
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 30
RANDOM_SEED = 42

# -----------------------------
# 1️⃣ DATA PREPARATION & METADATA
# -----------------------------
data = []

# Converts folder structure into a clean list.
for folder in os.listdir(DATASET_PATH):
    folder_path = os.path.join(DATASET_PATH, folder)
    
    if os.path.isdir(folder_path):
        # Translate label 4 the folders
        label = folder
        
        for file in os.listdir(folder_path):
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(folder_path, file)
                data.append([img_path, label])

# Converts the raw list into a structured table (DataFrame)
df = pd.DataFrame(data, columns=["image_path", "label"])

# Identifies all unique categories and sorts them alphabetically
class_names = sorted(df['label'].unique())
# Creates a dictionary to map text labels to integer IDs (Model readable)
label_map = {name: i for i, name in enumerate(class_names)}
# Creates a reverse dictionary to map IDs back to text labels (Human readable)
inv_label_map = {i: name for name, i in label_map.items()}

# Map labels to integers immediately in the DataFrame
df['label_code'] = df['label'].map(label_map)

print(f"Total images: {len(df)}")
print(f"Classes found: {len(class_names)}")
print(df['label'].value_counts().head())

# -----------------------------
# 2️⃣ TRAIN / TEST SPLIT
# -----------------------------
train_df, test_df = train_test_split(
    df,
    test_size=0.1,
    stratify=df['label'], # Stratify ensures all classes are represented
    random_state=RANDOM_SEED
)

print(f"Train size: {len(train_df)} | Test size: {len(test_df)}")

# -----------------------------
# 3️⃣ DATASET PIPELINE (tf.data)
# -----------------------------
def df_to_dataset(dataframe, shuffle=True, batch_size=32):
    # Get the list of files and labels
    paths = dataframe['image_path'].values
    labels = dataframe['label_code'].values
    
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    # Define Image Processing (Load -> Resize -> Normalize)
    def process_path(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
        img = img / 255.0  # Normalize [0, 1]
        return img, label
    
    # Apply processing to all images in parallel
    ds = ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)

    # Aleatory combination
    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe))

    # Group into packs of 32
    ds = ds.batch(batch_size)
    #Preload next pack in background (No Lag)
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)
    return ds

# Create the final pipelines
train_dataset = df_to_dataset(train_df, batch_size=BATCH_SIZE)
test_dataset = df_to_dataset(test_df, shuffle=False, batch_size=BATCH_SIZE)

# -----------------------------
# 4️⃣ MODEL ARCHITECTURE (CNN)
# -----------------------------
print(f"Building model for {len(class_names)} classes...")

model = models.Sequential([
    # Block 1
    layers.Conv2D(32, 3, activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    layers.MaxPooling2D(),

    # Block 2
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),

    # Block 3
    layers.Conv2D(96, 3, activation='relu'),
    layers.MaxPooling2D(),

    # Global pooling is generally more efficient than Flatten for modern CNNs
    layers.GlobalAveragePooling2D(),

    # Dense Layers
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.4), # Reduce overfitting

    # Output Layer
    layers.Dense(len(class_names), activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# -----------------------------
# 5️⃣ TRAINING
# -----------------------------
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=EPOCHS
)

# -----------------------------
# 6️⃣ EVALUATION & VISUALIZATION
# -----------------------------
# Evaluate on test set
test_loss, test_acc = model.evaluate(test_dataset)

train_acc = history.history['accuracy'][-1]
train_loss = history.history['loss'][-1]

print(f'Accuracy (Train): {train_acc}')
print(f'Loss (Train): {train_loss}')
print(f'Validation accuracy: {test_acc}')
print(f'Loss validation: {test_loss}')

# Plot Training History 
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Val Loss', color='orange') # Added validation loss
plt.title('Cross Entropy Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy', color='green')
plt.plot(history.history['val_accuracy'], label='Val Accuracy', color='red') # Added validation acc
plt.title('Classification Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Visualize Predictions
print("\n--- Sample Predictions ---")
for images, labels in test_dataset.take(1):
    preds = model.predict(images)
    pred_classes = np.argmax(preds, axis=1)

    # Show first image in batch
    img = images[0].numpy()
    true_label = inv_label_map[labels[0].numpy()]
    pred_label = inv_label_map[pred_classes[0]]
    
    print(f"Predicted: {pred_label} | Actual: {true_label}")
    
    plt.imshow(img)
    plt.title(f"Pred: {pred_label} | True: {true_label}")
    plt.axis('off')
    plt.show()
    break
# Out:
# Total images: 26179
# Classes found: 10
# label
# cane        4863
# ragno       4821
# gallina     3098
# cavallo     2623
# farfalla    2112
# Name: count, dtype: int64
# Train size: 23561 | Test size: 2618
# Building model for 10 classes...
# /Users/ia_dev/Downloads/yes/envs/ia-audio/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 52, 52, 96)     │        55,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 26, 26, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 96)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81,642 (318.91 KB)
#  Trainable params: 81,642 (318.91 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 2026-01-28 19:04:34.000947: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:34.246301: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:34.371550: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:34.680292: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:34.745969: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:34.936838: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:35.020065: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:35.839323: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:35.873098: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:35.883213: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:35.916382: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:36.215688: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:36.784042: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:36.838833: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:37.079888: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:37.405951: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:37.426835: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:37.482204: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:37.507661: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:37.586481: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1973 - loss: 2.2057
# 2026-01-28 19:04:57.571858: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:57.741574: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 25s 27ms/step - accuracy: 0.2250 - loss: 2.1576 - val_accuracy: 0.2960 - val_loss: 1.9672
# Epoch 2/30
# 2026-01-28 19:04:58.646336: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:58.905639: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:59.033714: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:59.354275: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:59.423455: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:59.630927: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:04:59.720890: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:00.598466: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:00.630057: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:00.641560: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:00.672176: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:00.969930: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:01.545191: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:01.596999: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:01.843049: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:02.137338: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:02.156221: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:02.211239: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:02.242464: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:02.331679: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 735/737 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2905 - loss: 2.0169
# 2026-01-28 19:05:21.365336: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:21.572080: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 24s 27ms/step - accuracy: 0.3054 - loss: 1.9774 - val_accuracy: 0.3663 - val_loss: 1.7672
# Epoch 3/30
# 2026-01-28 19:05:22.349160: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:22.609547: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:22.739917: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:23.065963: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:23.139941: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:23.346939: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:23.441219: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:24.341254: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:24.378407: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:24.390729: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:24.424683: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:24.748122: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:25.365328: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:25.421638: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:25.684536: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:25.981298: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:25.998557: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:26.052391: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:26.073427: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:26.153250: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 736/737 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3371 - loss: 1.8879
# 2026-01-28 19:05:45.274272: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:45.484689: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 24s 27ms/step - accuracy: 0.3465 - loss: 1.8567 - val_accuracy: 0.3644 - val_loss: 1.8198
# Epoch 4/30
# 2026-01-28 19:05:46.265601: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:46.525748: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:46.658405: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:46.981223: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:47.048750: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:47.256367: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:47.349743: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:48.212433: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:48.245735: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:48.257076: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:48.289688: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:48.597358: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:49.190977: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:49.245853: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:49.502699: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:49.785699: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:49.800102: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:49.845301: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:49.863148: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:05:49.940068: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 735/737 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3795 - loss: 1.7818
# 2026-01-28 19:06:08.762360: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:06:08.986600: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 24s 26ms/step - accuracy: 0.3813 - loss: 1.7683 - val_accuracy: 0.4209 - val_loss: 1.6098
# Epoch 5/30
# 2026-01-28 19:06:09.766806: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:06:10.012770: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:06:10.130149: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:06:10.422068: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:06:10.486431: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:06:10.676059: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:06:10.755055: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:06:11.574853: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:06:11.606155: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-28 19:06