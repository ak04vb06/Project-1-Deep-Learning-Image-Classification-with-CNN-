# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
from PIL import Image

# -----------------------------
# ⚙️ CONFIGURATION (change model = change paramethers)
# -----------------------------
DATASET_PATH = r"/Users/ia_dev/Desktop/Work/archive/raw-img" # need to change 
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 15
RANDOM_SEED = 42

# -----------------------------
# 1️⃣ DATA PREPARATION & METADATA
# -----------------------------
data = []

# Converts folder structure into a clean list.
for folder in os.listdir(DATASET_PATH):
    folder_path = os.path.join(DATASET_PATH, folder)
    
    if os.path.isdir(folder_path):
        # Translate label 4 the folders
        label = folder
        
        for file in os.listdir(folder_path):
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(folder_path, file)
                data.append([img_path, label])

# Converts the raw list into a structured table (DataFrame)
df = pd.DataFrame(data, columns=["image_path", "label"])

# Identifies all unique categories and sorts them alphabetically
class_names = sorted(df['label'].unique())
# Creates a dictionary to map text labels to integer IDs (Model readable)
label_map = {name: i for i, name in enumerate(class_names)}
# Creates a reverse dictionary to map IDs back to text labels (Human readable)
inv_label_map = {i: name for name, i in label_map.items()}

# Map labels to integers immediately in the DataFrame
df['label_code'] = df['label'].map(label_map)

print(f"Total images: {len(df)}")
print(f"Classes found: {len(class_names)}")
print(df['label'].value_counts().head())

# -----------------------------
# 2️⃣ TRAIN / TEST SPLIT
# -----------------------------
train_df, test_df = train_test_split(
    df,
    test_size=0.1,
    stratify=df['label'], # Stratify ensures all classes are represented
    random_state=RANDOM_SEED
)

print(f"Train size: {len(train_df)} | Test size: {len(test_df)}")

# -----------------------------
# 3️⃣ DATASET PIPELINE (tf.data)
# -----------------------------
def df_to_dataset(dataframe, shuffle=True, batch_size=32):
    # Get the list of files and labels
    paths = dataframe['image_path'].values
    labels = dataframe['label_code'].values
    
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    # Define Image Processing (Load -> Resize -> Normalize)
    def process_path(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
        img = img / 255.0  # Normalize [0, 1]
        return img, label
    
    # Apply processing to all images in parallel
    ds = ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)

    # Aleatory combination
    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe))

    # Group into packs of 32
    ds = ds.batch(batch_size)
    #Preload next pack in background (No Lag)
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)
    return ds

# Create the final pipelines
train_dataset = df_to_dataset(train_df, batch_size=BATCH_SIZE)
test_dataset = df_to_dataset(test_df, shuffle=False, batch_size=BATCH_SIZE)

# -----------------------------
# 4️⃣ MODEL ARCHITECTURE (CNN)
# -----------------------------
print(f"Building model for {len(class_names)} classes...")

model = models.Sequential([
    # Block 1
    layers.Conv2D(32, 3, activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    layers.MaxPooling2D(),

    # Block 2
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),

    # Block 3
    layers.Conv2D(96, 3, activation='relu'),
    layers.MaxPooling2D(),

    # Global pooling is generally more efficient than Flatten for modern CNNs
    layers.GlobalAveragePooling2D(),

    # Dense Layers
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.4), # Reduce overfitting

    # Output Layer
    layers.Dense(len(class_names), activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# -----------------------------
# 5️⃣ TRAINING
# -----------------------------
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=EPOCHS
)

# -----------------------------
# 6️⃣ EVALUATION & VISUALIZATION
# -----------------------------
# Evaluate on test set
test_loss, test_acc = model.evaluate(test_dataset)

train_acc = history.history['accuracy'][-1]
train_loss = history.history['loss'][-1]

print(f'Accuracy (Train): {train_acc}')
print(f'Loss (Train): {train_loss}')
print(f'Validation accuracy: {test_acc}')
print(f'Loss validation: {test_loss}')

# Plot Training History 
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Val Loss', color='orange') # Added validation loss
plt.title('Cross Entropy Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy', color='green')
plt.plot(history.history['val_accuracy'], label='Val Accuracy', color='red') # Added validation acc
plt.title('Classification Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Visualize Predictions
print("\n--- Sample Predictions ---")
for images, labels in test_dataset.take(1):
    preds = model.predict(images)
    pred_classes = np.argmax(preds, axis=1)

    # Show first image in batch
    img = images[0].numpy()
    true_label = inv_label_map[labels[0].numpy()]
    pred_label = inv_label_map[pred_classes[0]]
    
    print(f"Predicted: {pred_label} | Actual: {true_label}")
    
    plt.imshow(img)
    plt.title(f"Pred: {pred_label} | True: {true_label}")
    plt.axis('off')
    plt.show()
    break
# Out:
# Total images: 26179
# Classes found: 10
# label
# cane        4863
# ragno       4821
# gallina     3098
# cavallo     2623
# farfalla    2112
# Name: count, dtype: int64
# Train size: 23561 | Test size: 2618
# Building model for 10 classes...
# 2026-01-29 11:47:19.407550: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Max
# 2026-01-29 11:47:19.407573: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 36.00 GB
# 2026-01-29 11:47:19.407578: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 14.04 GB
# 2026-01-29 11:47:19.407590: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-01-29 11:47:19.407603: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /Users/ia_dev/Downloads/yes/envs/ia-audio/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 96)     │        55,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 96)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81,642 (318.91 KB)
#  Trainable params: 81,642 (318.91 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 2026-01-29 11:47:19.833819: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2026-01-29 11:47:20.320296: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:20.576846: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:20.706277: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:21.028376: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:21.097707: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:21.309889: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:21.399685: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:22.288891: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:22.326328: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:22.338697: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:22.373917: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:22.702979: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:23.305860: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:23.367195: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:23.631672: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:23.938920: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:23.955737: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:24.009377: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:24.030533: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:24.308339: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.1953 - loss: 2.2068
# 2026-01-29 11:47:45.923460: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:46.088098: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 27s 29ms/step - accuracy: 0.2143 - loss: 2.1753 - val_accuracy: 0.2674 - val_loss: 2.0447
# Epoch 2/15
# 2026-01-29 11:47:47.044305: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:47.311217: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:47.444478: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:47.765708: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:47.834026: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:48.035168: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:48.126503: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:49.001812: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:49.037771: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:49.049238: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:49.081021: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:49.398110: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:49.987712: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:50.045100: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:50.311568: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:50.622299: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:50.639531: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:50.693760: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:50.714928: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:47:50.802454: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 735/737 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2330 - loss: 2.1544
# 2026-01-29 11:48:10.550760: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:10.768400: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 25s 28ms/step - accuracy: 0.2415 - loss: 2.1415 - val_accuracy: 0.3235 - val_loss: 1.9895
# Epoch 3/15
# 2026-01-29 11:48:11.561502: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:11.832670: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:11.963694: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:12.290485: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:12.363770: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:12.574001: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:12.654223: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:13.498617: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:13.532051: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:13.542872: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:13.573923: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:13.876926: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:14.452372: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:14.506404: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:14.764830: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:15.060635: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:15.076946: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:15.125052: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:15.144450: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:15.238334: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 735/737 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2849 - loss: 2.0437
# 2026-01-29 11:48:34.948400: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:35.165265: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 24s 28ms/step - accuracy: 0.2953 - loss: 2.0039 - val_accuracy: 0.3266 - val_loss: 1.8204
# Epoch 4/15
# 2026-01-29 11:48:35.956463: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:36.212284: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:36.336633: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:36.639789: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:36.706619: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:36.901552: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:36.984636: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:37.843065: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:37.875135: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:37.886181: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:37.916167: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:38.224074: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:38.811216: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:38.867246: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:39.121468: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:39.397426: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:39.411348: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:39.456238: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:39.473229: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:39.538947: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 735/737 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3207 - loss: 1.9280
# 2026-01-29 11:48:59.286933: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:48:59.517565: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 24s 28ms/step - accuracy: 0.3274 - loss: 1.9116 - val_accuracy: 0.3373 - val_loss: 1.7872
# Epoch 5/15
# 2026-01-29 11:49:00.358295: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 2026-01-29 11:49